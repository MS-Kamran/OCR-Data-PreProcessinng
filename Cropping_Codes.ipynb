# %% [markdown]
# # **1st Page Letters**

# %% [markdown]
# # **Rotate**

# %%
from PIL import Image
import os

# Path to the folder containing images
folder_path = "/Users/mskamran/Documents/Data Science/All Types Of Datas/New Data/try"

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".jpg") or filename.endswith(".png"):  # Filter images by extension
        # Open the image file
        image_path = os.path.join(folder_path, filename)
        image = Image.open(image_path)

        # Rotate the image by 5 degrees clockwise
        rotated_image = image.rotate(2, expand=True)

        # Save the rotated image, you can change the saving format if needed
        rotated_image.save(os.path.join(folder_path, f"{filename}"))

print("All images rotated by 5 degrees.")

# %% [markdown]
# # **Crop Old Data 1st part**

# %%
#crop the images

import os, glob
from PIL import Image

#  array of all letters
bangla_alphabets = [
    'অ', 'ঋ', 'খ', 'জ', 'ঢ', 'ন', 'য', 'হ', 'ো', 'ে', 'ূ', '৪', 'ক্ষ', 'চ্ছ', 'স্থ', 'শ্র',
    'আ', 'এ', 'গ', 'ঝ', 'ণ', 'প', 'র', 'ড়', 'ঁ', 'ৈ', 'ৃ', '৫', 'ঞ্চ', 'ন্ত', 'হ্ণ', 'জ্ঞ',
    'ই', 'ঐ', 'ঘ', 'ঞ', 'ত', 'ফ', 'ল', 'ঢ়', 'া', 'ো', '০', '৬', 'ঞ্জ', 'ন্ড', 'হ্ন', 'দ্ব',
    'ঈ', 'ও', 'ঙ', 'ট', 'থ', 'ব', 'শ', 'য়', 'ি', 'ৌ', '১', '৭', 'ণ্ট', 'স্ত', 'ক্ল', 'ব্ল',
    'উ', 'ঔ', 'চ', 'ঠ', 'দ', 'ভ', 'ষ', 'ৎ', 'ী', '‍্য', '২', '৮', 'ক্ত', 'স্ট', 'ন্দ', 'ম্ন',
    'ঊ', 'ক', 'ছ', 'ড', 'ধ', 'ম', 'স', 'ং', 'ু', '্র', '৩', '৯', 'চ্চ', 'স্ত', 'ন্ন'
]

# coordinate of each image
sizes=[

       (1450,900,270,140),  (900,140,270,270),  (900,270,270,400),  (900,420,270,540),  (900,550,270,670),  (900,680,270,820),  (900,820,270,960),  (900,960,270,1100),  (900,1100,270,1250),  (900,1240,270,1380),  (900,1370,270,1520), (900,1510,270,1660),(900,1640,270,1800),(900,1790,270,1930),(900,1930,270,2070),(900,2070,270,2190),

       (410,0,560,140),  (410,140,560,270),  (410,270,560,400),  (410,420,560,540),  (410,550,560,670),  (410,680,560,820),  (410,820,560,960),  (410,960,560,1100),  (410,1100,560,1250),  (410,1240,560,1380),  (410,1370,560,1520),(410,1510,560,1660),(410,1640,560,1800),(410,1790,560,1930),(410,1930,560,2070),(410,2070,560,2190),

       (700,0,830,140),  (700,140,830,270),  (700,270,830,400),  (700,420,830,540),  (700,550,830,670),  (700,680,830,820),  (700,820,830,960),  (700,960,830,1100),  (700,1100,830,1250),  (700,1240,830,1380),  (700,1370,830,1520),(700,1510,830,1660),(700,1640,830,1800),(700,1790,830,1930),(700,1930,830,2070),(700,2070,830,2190),

       (980,0,1130,140), (980,140,1130,270), (980,270,1130,400), (980,420,1130,540), (980,550,1130,670), (980,680,1130,820), (980,820,1130,960), (980,960,1130,1100), (980,1100,1130,1250), (980,1240,1130,1380), (980,1370,1130,1520),(980,1510,1130,1660),(980,1640,1130,1800),(980,1790,1130,1930),(980,1930,1130,2070),(980,2070,1130,2190),

       (1250,0,1420,140),(1250,140,1420,270),(1250,270,1420,400),(1250,420,1420,540),(1250,550,1420,670),(1250,680,1420,820),(1250,820,1420,960),(1250,960,1420,1100),(1250,1100,1420,1250),(1250,1240,1420,1380),(1250,1370,1420,1520),(1250,1510,1420,1660),(1250,1640,1420,1800),(1250,1790,1420,1930),(1250,1930,1420,2070),(1250,2070,1420,2190),

       (1550,0,1700,140),(1550,140,1700,270),(1550,270,1700,400),(1550,420,1700,540),(1550,550,1700,670),(1550,680,1700,820),(1550,820,1700,960),(1550,960,1700,1100),(1550,1100,1700,1250),(1550,1240,1700,1380),(1550,1370,1700,1520),(1550,1510,1700,1660),(1550,1640,1700,1800),(1550,1790,1700,1930),(1550,1930,1700,2070)
]



# Define the base directory where your images are located
base_dir = "/Users/mskamran/Downloads/ML Class/Image without dotted lines/"

# Define the class and age directories
class_dir = "Class 10"
age_dir = "Class 10 age 15"

# Define the filename pattern
filename_pattern = "class 10 age 15_{}.jpg"

# Define the output directory for saving cropped images
output_dir = "/Users/mskamran/Downloads/ML Class/LettersClean/"

# Initialize index for Bangla alphabets and serial number
a = 0
serial_number = 1

# Loop through the range of serial numbers
for serial in range(1, 40):  # Adjust the range as needed
    # Construct the full file path
    filepath = os.path.join(base_dir, class_dir, age_dir, filename_pattern.format(serial))

    # Check if the file exists
    if os.path.exists(filepath):
        img = Image.open(filepath)
        for i in sizes:
            new = Image.new('RGB', (28, 28), color='white')
            imm = img.crop(box=(i))
            imm1 = imm.resize((28, 28))
            new.paste(imm1, (0, 0))

            # Get the current Bangla alphabet based on index
            current_alphabet = bangla_alphabets[a % len(bangla_alphabets)]

            # Construct the save path
            save_path = os.path.join(output_dir, class_dir, age_dir, f"clas10_age15_{current_alphabet}_{serial_number}.jpg")

            # Save the image
            new.save(save_path)

            # Increment the indices
            a += 1
            serial_number += 1

# %% [markdown]
# # **Array Of Crop Cordinate**

# %%
# Given array of tuples
array_of_tuples = [

       (4430, 1250, 4760, 1550), (4430, 1550, 4760, 1930), (4430, 1940, 4760, 2270), (4430, 2270, 4760, 2590), (4430, 2590, 4760, 2950), (4430, 2950, 4760, 3250), (4430, 3250, 4760, 3600), (4430, 3600, 4760, 3950), (4430, 3950, 4760, 4280), (4430, 4280, 4760, 4650), (4430, 4650, 4760, 4970), (4430, 4970, 4760, 5300), (4430, 5300, 4760, 5620), (4430, 5620, 4760, 5950), (4430, 5950, 4760, 6280)

    ]

# New value to replace 900
replacement_value = 4470

# Replace 900 with the new value in each tuple
modified_array = [(replacement_value if item == 4430 else item) for tup in array_of_tuples for item in tup]

# Reshape the modified array back to a list of tuples
modified_array_of_tuples = [modified_array[i:i+4] for i in range(0, len(modified_array), 4)]

# Join all the tuples into a single string separated by commas
modified_array_string = ', '.join([str(tup) for tup in modified_array_of_tuples])

# Replace square brackets with round brackets
modified_array_string = modified_array_string.replace('[', '(').replace(']', ')')

# Print the modified array as a single string
print(modified_array_string)

# %% [markdown]
# # **OLD Data Letters**

# %% [markdown]
# **type 1**

# %%
#1
import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'ঋ', 'খ', 'জ', 'ঢ', 'ন', 'য', 'হ', 'ো', 'ে', 'ূ', '৪', 'ক্ষ', 'চ্ছ', 'স্থ', 'শ্র',
    'আ', 'এ', 'গ', 'ঝ', 'ণ', 'প', 'র', 'ড়', 'ঁ', 'ৈ', 'ৃ', '৫', 'ঞ্চ', 'ন্ত', 'হ্ণ', 'জ্ঞ',
    'ই', 'ঐ', 'ঘ', 'ঞ', 'ত', 'ফ', 'ল', 'ঢ়', 'া', 'ো', '০', '৬', 'ঞ্জ', 'ন্ড', 'হ্ন', 'দ্ব',
    'ঈ', 'ও', 'ঙ', 'ট', 'থ', 'ব', 'শ', 'য়', 'ি', 'ৌ', '১', '৭', 'ণ্ট', 'স্ত', 'ক্ল', 'ব্ল',
    'উ', 'ঔ', 'চ', 'ঠ', 'দ', 'ভ', 'ষ', 'ৎ', 'ী', '‍্য', '২', '৮', 'ক্ত', 'স্ট', 'ন্দ', 'ম্ন',
    'ঊ', 'ক', 'ছ', 'ড', 'ধ', 'ম', 'স', 'ং', 'ু', '্র', '৩', '৯', 'চ্চ', 'স্ত', 'ন্ন'
]

# coordinate of each image
sizes = [

       (900, 1440, 1300, 1760),  (900, 1770, 1300, 2060),  (900, 2080, 1300, 2360),  (900, 2370, 1300, 2660),  (900, 2680, 1300, 2960),  (900, 2980, 1300, 3260),  (900, 3280, 1300, 3560),  (900, 3580, 1300, 3860),  (900, 3880, 1300, 4160),  (900, 4180, 1300, 4470),  (900, 4480, 1300, 4770),  (900, 4780, 1300, 5080),  (900, 5080, 1300, 5380),  (900, 5380, 1300, 5680),  (900, 5680, 1300, 5980),  (900, 5980, 1300, 6280),

       (1580, 1440, 1970, 1760), (1580, 1770, 1970, 2060), (1580, 2080, 1970, 2360), (1580, 2370, 1970, 2660), (1580, 2680, 1970, 2960), (1580, 2980, 1970, 3260), (1580, 3280, 1970, 3560), (1580, 3580, 1970, 3860), (1580, 3880, 1970, 4160), (1580, 4180, 1970, 4470), (1580, 4480, 1970, 4770), (1580, 4780, 1970, 5080), (1580, 5080, 1970, 5380), (1580, 5380, 1970, 5680), (1580, 5680, 1970, 5980), (1580, 5980, 1970, 6280),

       (2250, 1440, 2620, 1760), (2250, 1770, 2620, 2060), (2250, 2080, 2620, 2360), (2250, 2370, 2620, 2660), (2250, 2680, 2620, 2960), (2250, 2980, 2620, 3260), (2250, 3280, 2620, 3560), (2250, 3580, 2620, 3860), (2250, 3880, 2620, 4160), (2250, 4180, 2620, 4470), (2250, 4480, 2620, 4770), (2250, 4780, 2620, 5080), (2250, 5080, 2620, 5380), (2250, 5380, 2620, 5680), (2250, 5680, 2620, 5980), (2250, 5980, 2620, 6280),

       (2920, 1440, 3280, 1760), (2920, 1770, 3280, 2060), (2920, 2080, 3280, 2360), (2920, 2370, 3280, 2660), (2920, 2680, 3280, 2960), (2920, 2980, 3280, 3260), (2920, 3280, 3280, 3560), (2920, 3580, 3280, 3860), (2920, 3880, 3280, 4160), (2920, 4180, 3280, 4470), (2920, 4480, 3280, 4770), (2920, 4780, 3280, 5080), (2920, 5080, 3280, 5380), (2920, 5380, 3280, 5680), (2920, 5680, 3280, 5980), (2920, 5980, 3280, 6280),

       (3580, 1440, 3940, 1760), (3580, 1770, 3940, 2060), (3580, 2080, 3940, 2360), (3580, 2370, 3940, 2660), (3580, 2680, 3940, 2960), (3580, 2980, 3940, 3260), (3580, 3280, 3940, 3560), (3580, 3580, 3940, 3860), (3580, 3880, 3940, 4160), (3580, 4180, 3940, 4470), (3580, 4480, 3940, 4770), (3580, 4780, 3940, 5080), (3580, 5080, 3940, 5380), (3580, 5380, 3940, 5680), (3580, 5680, 3940, 5980), (3580, 5980, 3940, 6280),

       (4270, 1440, 4640, 1760), (4270, 1770, 4640, 2060), (4270, 2080, 4640, 2360), (4270, 2370, 4640, 2660), (4270, 2680, 4640, 2960), (4270, 2980, 4640, 3260), (4270, 3280, 4640, 3560), (4270, 3580, 4640, 3860), (4270, 3880, 4640, 4160), (4270, 4180, 4640, 4470), (4270, 4480, 4640, 4770), (4270, 4780, 4640, 5080), (4270, 5080, 4640, 5380), (4270, 5380, 4640, 5680), (4270, 5680, 4640, 5980)
]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /type 1 dot remove'
destination_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /1'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# **Type 2**

# %%
#2
import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'ঋ', 'খ', 'জ', 'ঢ', 'ন', 'য', 'হ', 'ো', 'ে', 'ূ', '৪', 'ক্ষ', 'চ্ছ', 'স্থ', 'শ্র',
       (3670, 1250, 4050, 1550), (3670, 1550, 4050, 1930), (3670, 1940, 4050, 2270), (3670, 2270, 4050, 2590), (3670, 2590, 4050, 2950), (3670, 2950, 4050, 3250), (3670, 3250, 4050, 3600), (3670, 3600, 4050, 3950), (3670, 3950, 4050, 4280), (3670, 4280, 4050, 4650), (3670, 4650, 4050, 4970), (3670, 4970, 4050, 5300), (3670, 5300, 4050, 5620), (3670, 5620, 4050, 5950), (3670, 5950, 4050, 6280), (3670, 6280, 4050, 6600),

       (4430, 1250, 4760, 1550), (4430, 1550, 4760, 1930), (4430, 1940, 4760, 2270), (4430, 2270, 4760, 2590), (4430, 2590, 4760, 2950), (4430, 2950, 4760, 3250), (4430, 3250, 4760, 3600), (4430, 3600, 4760, 3950), (4430, 3950, 4760, 4280), (4430, 4280, 4760, 4650), (4430, 4650, 4760, 4970), (4430, 4970, 4760, 5300), (4430, 5300, 4760, 5620), (4430, 5620, 4760, 5950), (4430, 5950, 4760, 6280)

]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /type 2 dot remove'
destination_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /2'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %%
#2
import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'ঋ', 'খ', 'জ', 'ঢ', 'ন', 'য', 'হ', 'ো', 'ে', 'ূ', '৪', 'ক্ষ', 'চ্ছ', 'স্থ', 'শ্র',
    'আ', 'এ', 'গ', 'ঝ', 'ণ', 'প', 'র', 'ড়', 'ঁ', 'ৈ', 'ৃ', '৫', 'ঞ্চ', 'ন্ত', 'হ্ণ', 'জ্ঞ',
    'ই', 'ঐ', 'ঘ', 'ঞ', 'ত', 'ফ', 'ল', 'ঢ়', 'া', 'ো', '০', '৬', 'ঞ্জ', 'ন্ড', 'হ্ন', 'দ্ব',
    'ঈ', 'ও', 'ঙ', 'ট', 'থ', 'ব', 'শ', 'য়', 'ি', 'ৌ', '১', '৭', 'ণ্ট', 'স্ত', 'ক্ল', 'ব্ল',
       (4430, 1250, 4760, 1550), (4430, 1550, 4760, 1930), (4430, 1940, 4760, 2270), (4430, 2270, 4760, 2590), (4430, 2590, 4760, 2950), (4430, 2950, 4760, 3250), (4430, 3250, 4760, 3600), (4430, 3600, 4760, 3950), (4430, 3950, 4760, 4280), (4430, 4280, 4760, 4650), (4430, 4650, 4760, 4970), (4430, 4970, 4760, 5300), (4430, 5300, 4760, 5620), (4430, 5620, 4760, 5950), (4430, 5950, 4760, 6280)

]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /type 2 dot remove'
destination_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/Old Data /2'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# **type 0**

# %%
#0

import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'ঋ', 'খ', 'জ', 'ঢ', 'ন', 'য', 'হ', 'ো', 'ে', 'ূ', '৪', 'ক্ষ', 'চ্ছ', 'স্থ', 'শ্র',
    'আ', 'এ', 'গ', 'ঝ', 'ণ', 'প', 'র', 'ড়', 'ঁ', 'ৈ', 'ৃ', '৫', 'ঞ্চ', 'ন্ত', 'হ্ণ', 'জ্ঞ',
    'ই', 'ঐ', 'ঘ', 'ঞ', 'ত', 'ফ', 'ল', 'ঢ়', 'া', 'ো', '০', '৬', 'ঞ্জ', 'ন্ড', 'হ্ন', 'দ্ব',
    'ঈ', 'ও', 'ঙ', 'ট', 'থ', 'ব', 'শ', 'য়', 'ি', 'ৌ', '১', '৭', 'ণ্ট', 'স্ত', 'ক্ল', 'ব্ল',
    'উ', 'ঔ', 'চ', 'ঠ', 'দ', 'ভ', 'ষ', 'ৎ', 'ী', '‍্য', '২', '৮', 'ক্ত', 'স্ট', 'ন্দ', 'ম্ন',
    'ঊ', 'ক', 'ছ', 'ড', 'ধ', 'ম', 'স', 'ং', 'ু', '্র', '৩', '৯', 'চ্চ', 'স্ত', 'ন্ন'
]

# coordinate of each image
sizes = [

if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **Crop Letters For New Data**

# %% [markdown]
# # **SCANNER IMAGES**

# %%
import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ',
    'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক',
    'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ',
    'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড',
    'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ',
    'ন', 'প', 'ফ', 'ব', 'ভ', 'ম',
    'য', 'র', 'ল', 'শ', 'ষ', 'স',
    'হ', 'ড়', 'ঢ়', 'য়', 'ৎ', 'ং',
    'ো', 'ঁ', 'া', 'ি', 'ী', 'ু',
    'ে', 'ৈ', 'ৌ', '‍্য', '্র', 'ৃ',
    'ূ', 'ঃ', '১', '২', '৩', '৪',
    '৫', '৬', '৭', '৮', '৯', '০',
    'ক্ষ', 'ঞ্চ', 'ঞ্জ', 'ণ্ট', 'ক্ত', 'ন্ন',
    'চ্ছ', 'ন্ত', 'ন্ড', 'স্ত', 'স্ট', 'জ্জ',
    'স্থ', 'হ্ণ', 'হ্ন', 'ক্ল', 'ন্দ', 'ত্ম',
    'শ্র', 'জ্ঞ', 'দ্ব', 'ব্ল', 'ম্ন', 'দ্ধ'
]

# coordinate of each image
sizes = [
    #'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ',
    (780, 1150, 1160, 1440), (1480, 1150, 1860, 1440), (2180, 1150, 2560, 1440), (2880, 1150, 3280, 1440), (3580, 1150, 4000, 1440), (4350, 1150, 4740, 1440),
    #'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক',
    (780, 1420, 1160, 1730), (1480, 1420, 1860, 1730), (2180, 1420, 2560, 1730), (2880, 1420, 3280, 1730), (3580, 1420, 4000, 1730), (4350, 1420, 4740, 1730),
    (780, 5400, 1160, 5730), (1480, 5400, 1860, 5730), (2180, 5400, 2560, 5730), (2880, 5400, 3280, 5730), (3580, 5400, 4000, 5730), (4350, 5400, 4740, 5730),
    #'স্থ', 'হ্ণ', 'হ্ন', 'ক্ল', 'ন্দ', 'ত্ম',
    (780, 5730, 1160, 6070), (1480, 5730, 1860, 6070), (2180, 5730, 2560, 6070), (2880, 5730, 3280, 6070), (3580, 5730, 4000, 6070), (4350, 5730, 4740, 6070),
    #'শ্র', 'জ্ঞ', 'দ্ব', 'ব্ল', 'ম্ন', 'দ্ধ'
    (780, 6055, 1160, 6400), (1480, 6055, 1860, 6400), (2180, 6055, 2560, 6400), (2880, 6055, 3280, 6400), (3580, 6055, 4000, 6400), (4350, 6055, 4740, 6400),

         ]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/New Data/P1 dot remove'
destination_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/New Data/P1 Scan Crop Letters '

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **Missing Letters**

# %%
# SCANNER IMAGES

import os
from PIL import Image

# array of all letters
bangla_alphabets = ['৬', '৭', '৮', '৯', '০']

# coordinate of each image
sizes = [
    #'৬', '৭', '৮', '৯', '০',
    (1580, 4850, 1850, 5110), (2270, 4870, 2510, 5110), (2940, 4860, 3180, 5090), (3650, 4870, 3900, 5100), (4400, 4850, 4640, 5080),
         ]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/New Data/P1 dot remove'
destination_dir = '/Users/mskamran/Documents/Data Science/All Types Of Datas/New Data/missing letters'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **MOBILE CROP**

# %%
import os
from PIL import Image

# array of all letters
bangla_alphabets = [
    'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ',
    'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক',
    'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ',
    'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড',
    'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ',
    'ন', 'প', 'ফ', 'ব', 'ভ', 'ম',
    'য', 'র', 'ল', 'শ', 'ষ', 'স',
    'হ', 'ড়', 'ঢ়', 'য়', 'ৎ', 'ং',
    'ো', 'ঁ', 'া', 'ি', 'ী', 'ু',
    'ে', 'ৈ', 'ৌ', '‍্য', '্র', 'ৃ',
    'ূ', 'ঃ', '১', '২', '৩', '৪',
    '৫', '৬', '৭', '৮', '৯', '০',
    'ক্ষ', 'ঞ্চ', 'ঞ্জ', 'ণ্ট', 'ক্ত', 'ন্ন',
    'চ্ছ', 'ন্ত', 'ন্ড', 'স্ত', 'স্ট', 'জ্জ',
    'স্থ', 'হ্ণ', 'হ্ন', 'ক্ল', 'ন্দ', 'ত্ম',
    'শ্র', 'জ্ঞ', 'দ্ব', 'ব্ল', 'ম্ন', 'দ্ধ'
]

# coordinate of each image
sizes = [
    #'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঊ',
    (800, 1150, 1150, 1420), (1550, 1150, 1850, 1420), (2250, 1150, 2550, 1420), (2950, 1150, 3250, 1420), (3650, 1150, 3950, 1420), (4350, 1150, 4650, 1420),
    #'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক',
    (800, 1420, 1150, 1750), (1550, 1420, 1850, 1750), (2250, 1420, 2550, 1750), (2950, 1420, 3250, 1750), (3650, 1420, 3950, 1750), (4350, 1420, 4650, 1750),
    #'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ',
    (800, 1740, 1150, 2130), (1550, 1740, 1850, 2130), (2250, 1740, 2550, 2130), (2950, 1740, 3250, 2130), (3650, 1740, 3950, 2130), (4350, 1740, 4650, 2130),
    #'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড',
    (800, 2080, 1150, 2480), (1550, 2080, 1850, 2480), (2250, 2080, 2550, 2480), (2950, 2080, 3250, 2480), (3650, 2080, 3950, 2480), (4350, 2080, 4650, 2480),
    #'শ্র', 'জ্ঞ', 'দ্ব', 'ব্ল', 'ম্ন', 'দ্ধ'
    (800, 6250, 1150, 6570), (1550, 6250, 1850, 6570), (2250, 6250, 2550, 6570), (2950, 6250, 3250, 6570), (3650, 6250, 3950, 6570), (4350, 6250, 4650, 6570),

         ]


# White background size
background_size = (512, 512)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/untitled folder 2'
destination_dir = '/Users/mskamran/Documents/Data Science/untitled folder 3'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **Crop For Page2**

# %% [markdown]
# # **Scanned**

# %%
import os
from PIL import Image

# array of all letters
bangla_alphabets = [ '1' ,'2' , '3']

# coordinate of each image
sizes = [ (300, 1300, 5000, 3550) , (300, 3900, 5000, 5400), (300, 5730, 5000, 6900)]


# White background size
background_size = (5000, 2000)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/P2 process/Scanned Dot Remove'
destination_dir = '/Users/mskamran/Documents/Data Science/P2 process/Scanned Crop'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **Mobile Crop**

# %%
import os
from PIL import Image

# array of all letters
bangla_alphabets = [ '1' ,'2' , '3']

# coordinate of each image
sizes = [ (300, 1100, 5000, 3550) , (300, 3950, 5000, 5450), (300, 5800, 5000, 6900)]


# White background size
background_size = (5000, 2000)

# Iterate through each file in the source directory
source_dir = '/Users/mskamran/Documents/Data Science/P2 process/Mobile dot remove '
destination_dir = '/Users/mskamran/Documents/Data Science/P2 process/Mobile Crop'

# Create destination directory if it doesn't exist
if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for filename in os.listdir(source_dir):
    # Check if the file is an image
    if filename.endswith('.jpg') or filename.endswith('.png') or filename.endswith('.jpeg'):
        # Read the image
        img = Image.open(os.path.join(source_dir, filename))

        # Iterate through each cropping size and save the cropped images
        for idx, size in enumerate(sizes):
            # Crop the image according to the size
            cropped_img = img.crop(size)

            # Create a new white background image
            new = Image.new('RGB', background_size, color='white')

            # Calculate position to paste the cropped image in the center
            x_offset = (background_size[0] - cropped_img.size[0]) // 2
            y_offset = (background_size[1] - cropped_img.size[1]) // 2

            # Paste the cropped image onto the new background
            new.paste(cropped_img, (x_offset, y_offset))

            # Split the filename and extension
            filename_parts = filename.split('.')
            if len(filename_parts) > 1:
                filename_without_extension = '.'.join(filename_parts[:-1])
                file_extension = filename_parts[-1]
            else:
                filename_without_extension = filename
                file_extension = 'jpg'  # Set a default extension if none is found

            # Construct the new filename with the original image name and the corresponding alphabet
            new_filename = f"{filename_without_extension}_{bangla_alphabets[idx]}.{file_extension}"

            # Save the image to the destination directory
            new.save(os.path.join(destination_dir, new_filename))

# %% [markdown]
# # **Crop Just Letters Without Size White Box**

# %% [markdown]
# # **Average contour size**

# %%
import os
import cv2

def calculate_average_contour_size(folder_path):
    total_contour_area = 0
    total_contours = 0

    # Iterate through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is an image
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Read the image
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)

            # Convert image to grayscale
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Threshold the grayscale image to get a binary image
            _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

            # Invert the binary image so that black becomes white and vice versa
            inverted_binary = cv2.bitwise_not(binary)

            # Find contours of the inverted binary image
            contours, _ = cv2.findContours(inverted_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Iterate over all contours in the image
            for contour in contours:
                # Calculate the area of the contour and add it to the total area
                total_contour_area += cv2.contourArea(contour)
                total_contours += 1

    # Calculate the average contour size
    if total_contours != 0:
        average_contour_size = total_contour_area / total_contours
        print("Average contour size:", average_contour_size)
    else:
        print("No contours found in the images.")

# Provide the folder path containing the images
folder_path = '/Users/mskamran/Documents/Data Science/Data Sets Without Augmentation/mix 512'
calculate_average_contour_size(folder_path)

# %%
import os
import cv2

def calculate_contour_difference(folder_path):
    # Initialize variables to store total difference and count of images processed
    total_difference = 0
    image_count = 0

    # Iterate through all files and folders recursively
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            # Check if the file is an image
            if filename.endswith(".jpg") or filename.endswith(".png"):
                # Read the image
                image_path = os.path.join(root, filename)
                image = cv2.imread(image_path)

                # Convert image to grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Threshold the grayscale image to get a binary image
                _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

                # Invert the binary image so that black becomes white and vice versa
                inverted_binary = cv2.bitwise_not(binary)

                # Find contours of the inverted binary image
                contours, _ = cv2.findContours(inverted_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Check if there are contours
                if len(contours) > 0:
                    # Sort contours by area in ascending order
                    sorted_contours = sorted(contours, key=cv2.contourArea)

                    # Calculate the areas of the largest and smallest contours
                    smallest_area = cv2.contourArea(sorted_contours[0])
                    largest_area = cv2.contourArea(sorted_contours[-1])

                    # Calculate the difference in areas
                    contour_difference = abs(largest_area - smallest_area)

                    # Add the difference to the total
                    total_difference += contour_difference
                    image_count += 1

    # Calculate the average difference
    if image_count > 0:
        average_difference = total_difference / image_count
    else:
        average_difference = 0

    return average_difference

# Provide the folder path containing the images
folder_path = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/চ'
average_difference = calculate_contour_difference(folder_path)
print(f"Average difference between the areas of the largest and smallest contours in each image: {average_difference}")

# %% [markdown]
# # **Can not Crop Two Contours**

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread('/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/try/Chattogram_Baishari School Bandarban_C6_M_A12_P1_2518_চ.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection using Canny
edges = cv2.Canny(blurred, 50, 150)

# Find contours in the edged image
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Get the largest contour
largest_contour = max(contours, key=cv2.contourArea)

# Get the bounding box of the largest contour
x, y, w, h = cv2.boundingRect(largest_contour)

# Crop the image using the bounding box
cropped_image = img[y:y+h, x:x+w]

# Display the cropped image
plt.imshow(cropped_image)
plt.axis('off')
plt.show()

# %%
import os
import cv2
import matplotlib.pyplot as plt

def crop_and_save_image(input_folder, output_folder):
    # Iterate through all files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Read the image
            img_path = os.path.join(input_folder, filename)
            img = cv2.imread(img_path)

            # Convert the image to grayscale
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Apply Gaussian blur to reduce noise
            blurred = cv2.GaussianBlur(gray, (5, 5), 0)

            # Perform edge detection using Canny
            edges = cv2.Canny(blurred, 50, 150)

            # Find contours in the edged image
            contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            # Check if contours were found
            if contours:
                # Get the largest contour
                largest_contour = max(contours, key=cv2.contourArea)

                # Get the bounding box of the largest contour
                x, y, w, h = cv2.boundingRect(largest_contour)

                # Crop the image using the bounding box
                cropped_image = img[y:y+h, x:x+w]

                # Save the cropped image to the output folder
                output_path = os.path.join(output_folder, filename)
                cv2.imwrite(output_path, cropped_image)

                print(f"Saved cropped image {filename} to {output_folder}")
            else:
                print(f"No contours found in {filename}")

# Provide the input folder and output folder paths
input_folder = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/চ'
output_folder = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/try'

crop_and_save_image(input_folder, output_folder)

# %% [markdown]
# # **Can Crop Two Contours in one image**

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
img = cv2.imread('/Users/mskamran/Documents/Data Science/P2 process/Mobile dot remove /Bandarban_Madinatul Model Madrasa_C5_F_A11_P2_2781.png')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection using Canny
edges = cv2.Canny(blurred, 50, 150)

# Find contours in the edged image
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Get bounding rectangles for all contours
bounding_rects = [cv2.boundingRect(contour) for contour in contours]

# Calculate the bounding box that encloses all rectangles
x_min = min(rect[0] for rect in bounding_rects)
y_min = min(rect[1] for rect in bounding_rects)
x_max = max(rect[0] + rect[2] for rect in bounding_rects)
y_max = max(rect[1] + rect[3] for rect in bounding_rects)

# Crop the image using the bounding box
cropped_image = img[y_min:y_max, x_min:x_max]

# Display the cropped image
plt.imshow(cropped_image)
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/Users/mskamran/Documents/Data Science/P2 process/Old Dot Remove/Dhaka_Ideal School_C10_M_A14_P2_1020.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection using Canny
edges = cv2.Canny(blurred, 50, 150)

# Find contours in the edged image
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Get bounding rectangles for all contours
bounding_rects = [cv2.boundingRect(contour) for contour in contours]

# Calculate the bounding box that encloses all rectangles
x_min = min(rect[0] for rect in bounding_rects)
y_min = min(rect[1] for rect in bounding_rects)
x_max = max(rect[0] + rect[2] for rect in bounding_rects)
y_max = max(rect[1] + rect[3] for rect in bounding_rects)

# Crop the image using the bounding box
cropped_image = img[y_min:y_max, x_min:x_max]

# Create a white canvas of size 512x512 pixels
canvas = np.ones((512, 512, 3), dtype=np.uint8) * 255

# Calculate position to paste the cropped image onto the canvas
x_offset = (512 - (x_max - x_min)) // 2
y_offset = (512 - (y_max - y_min)) // 2

# Paste the cropped image onto the canvas
canvas[y_offset:y_offset + (y_max - y_min), x_offset:x_offset + (x_max - x_min)] = cropped_image

# Display the canvas with the cropped image
plt.imshow(canvas)
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('/Users/mskamran/Documents/Data Science/P2 process/Old Dot Remove/Dhaka_Ideal School_C10_M_A14_P2_1020.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Perform edge detection using Canny
edges = cv2.Canny(blurred, 50, 150)

# Find contours in the edged image
contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Get bounding rectangles for all contours
bounding_rects = [cv2.boundingRect(contour) for contour in contours]

# Calculate the bounding box that encloses all rectangles
x_min = min(rect[0] for rect in bounding_rects)
y_min = min(rect[1] for rect in bounding_rects)
x_max = max(rect[0] + rect[2] for rect in bounding_rects)
y_max = max(rect[1] + rect[3] for rect in bounding_rects)

# Crop the image using the bounding box
cropped_image = img[y_min:y_max, x_min:x_max]

# Resize the cropped image to fit perfectly inside a 512x512 canvas without stretching
max_dimension = max(cropped_image.shape)
scale_factor = 512 / max_dimension
resized_image = cv2.resize(cropped_image, None, fx=scale_factor, fy=scale_factor)

# Create a white canvas of size 512x512 pixels
canvas = np.ones((512, 512, 3), dtype=np.uint8) * 255

# Calculate position to paste the resized image onto the canvas
x_offset = (512 - resized_image.shape[1]) // 2
y_offset = (512 - resized_image.shape[0]) // 2

# Paste the resized image onto the canvas
canvas[y_offset:y_offset + resized_image.shape[0], x_offset:x_offset + resized_image.shape[1]] = resized_image

# Display the canvas with the cropped image
plt.imshow(canvas)
plt.axis('off')
plt.show()

# %% [markdown]
# # **Worked Perfect till now FINAL Crop USING Contours**

# %%
import cv2
import numpy as np
import os


input_folder = '/Users/mskamran/Documents/Data Science/P2 process/Old Gray'
output_folder = '/Users/mskamran/Documents/Data Science/P2 process/Old Dot Remove'

# Function to process and save each image
def process_and_save_image(input_path, output_path):
    # Read the image
    img = cv2.imread(input_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Perform edge detection using Canny
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours in the edged image
    contours, _ = cv2.findContours(edges.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Check if contours were found
    if not contours:
        print(f"No contours found in {input_path}. Skipping...")
        return

    # Get bounding rectangles for all contours
    bounding_rects = [cv2.boundingRect(contour) for contour in contours]

    # Calculate the bounding box that encloses all rectangles
    x_min = min(rect[0] for rect in bounding_rects)
    y_min = min(rect[1] for rect in bounding_rects)
    x_max = max(rect[0] + rect[2] for rect in bounding_rects)
    y_max = max(rect[1] + rect[3] for rect in bounding_rects)

    # Crop the image using the bounding box
    cropped_image = img[y_min:y_max, x_min:x_max]

    # Resize the cropped image to fit perfectly inside a 512x512 canvas without stretching
    max_dimension = max(cropped_image.shape)
    scale_factor = 512 / max_dimension
    resized_image = cv2.resize(cropped_image, None, fx=scale_factor, fy=scale_factor)

    # Create a white canvas of size 512x512 pixels
    canvas = np.ones((512, 512, 3), dtype=np.uint8) * 255

    # Calculate position to paste the resized image onto the canvas
    x_offset = (512 - resized_image.shape[1]) // 2
    y_offset = (512 - resized_image.shape[0]) // 2

    # Paste the resized image onto the canvas
    canvas[y_offset:y_offset + resized_image.shape[0], x_offset:x_offset + resized_image.shape[1]] = resized_image

    # Save the canvas with the cropped image
    cv2.imwrite(output_path, canvas)

# Iterate through all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):  # Assuming images are JPG or PNG
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        process_and_save_image(input_path, output_path)

# %% [markdown]
# # **Coping Image which have Less then 10 contour**

# %%
import os
import cv2
import shutil

def copy_images_with_small_contours(folder_path):
    junk_folder = '/Users/mskamran/Documents/Data Science/Data Sets Without Augmentation/white'

    # Create the "Junk" folder if it doesn't exist
    if not os.path.exists(junk_folder):
        os.makedirs(junk_folder)

    # Iterate through all files and folders recursively
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            # Check if the file is an image
            if filename.endswith(".jpg") or filename.endswith(".png"):
                # Read the image
                image_path = os.path.join(root, filename)
                image = cv2.imread(image_path)

                # Convert image to grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Threshold the grayscale image to get a binary image
                _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

                # Invert the binary image so that black becomes white and vice versa
                inverted_binary = cv2.bitwise_not(binary)

                # Find contours of the inverted binary image
                contours, _ = cv2.findContours(inverted_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Initialize flag to indicate if image should be copied
                copy_image = True

                # Iterate over all contours in the image
                for contour in contours:
                    # Calculate the area of the contour
                    contour_area = cv2.contourArea(contour)

                    if contour_area < 10:
                        copy_image = False
                        break

                if copy_image:
                    # Copy the image to the "Junk" folder
                    shutil.copy(image_path, junk_folder)
                    print(f"Copied {filename} to Junk folder.")

# Provide the folder path containing the images
folder_path = '/Users/mskamran/Documents/Data Science/Data Sets Without Augmentation/mix 512'
copy_images_with_small_contours(folder_path)

# %%
import os
import cv2
import shutil

def count_images_with_large_contours(folder_path, min_contour_count):
    # Counter for images with large contours
    large_contour_count = 0

    # Iterate through all files and folders recursively
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            # Check if the file is an image
            if filename.endswith(".jpg") or filename.endswith(".png"):
                # Read the image
                image_path = os.path.join(root, filename)
                image = cv2.imread(image_path)

                # Convert image to grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Threshold the grayscale image to get a binary image
                _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

                # Invert the binary image so that black becomes white and vice versa
                inverted_binary = cv2.bitwise_not(binary)

                # Find contours of the inverted binary image
                contours, _ = cv2.findContours(inverted_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Check if the number of contours exceeds the specified threshold
                if len(contours) > min_contour_count:
                    large_contour_count += 1

    return large_contour_count

# Provide the folder path containing the images
folder_path = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/Split by letters/ঘ'
min_contour_count = 5  # Example: Minimum number of contours to consider an image as having large contours
count = count_images_with_large_contours(folder_path, min_contour_count)
print(f"Number of images with more than {min_contour_count} contours: {count}")

# %% [markdown]
# # **Move code which have less contours then 5**

# %%
import os
import cv2
import shutil

def move_images_with_small_contours(folder_path):
    junk_folder = '/Users/mskamran/Documents/Data Science/Data Sets Without Augmentation/white'

    # Create the "Junk" folder if it doesn't exist
    if not os.path.exists(junk_folder):
        os.makedirs(junk_folder)

    # Iterate through all files and folders recursively
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            # Check if the file is an image
            if filename.endswith(".jpg") or filename.endswith(".png"):
                # Read the image
                image_path = os.path.join(root, filename)
                image = cv2.imread(image_path)

                # Convert image to grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Threshold the grayscale image to get a binary image
                _, binary = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

                # Invert the binary image so that black becomes white and vice versa
                inverted_binary = cv2.bitwise_not(binary)

                # Find contours of the inverted binary image
                contours, _ = cv2.findContours(inverted_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Initialize flag to indicate if image should be moved
                move_image = True

                # Iterate over all contours in the image
                for contour in contours:
                    # Calculate the area of the contour
                    contour_area = cv2.contourArea(contour)

                    if contour_area < 5:
                        move_image = False
                        break

                if move_image:
                    # Get the destination path
                    dest_path = os.path.join(junk_folder, filename)
                    # Move the image to the "Junk" folder
                    shutil.move(image_path, dest_path)
                    print(f"Moved {filename} to Junk folder.")

# Provide the folder path containing the images
folder_path = '/Users/mskamran/Documents/Data Science/Data Sets Without Augmentation/mix 512'
move_images_with_small_contours(folder_path)

# %%
import os
import csv
import shutil

def copy_images_matching_csv(csv_file, image_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Read the CSV file and extract filenames
    with open(csv_file, 'r', newline='') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header if exists
        filenames = [row[0] for row in reader]

    # Iterate through the image folder
    for root, _, files in os.walk(image_folder):
        for filename in files:
            # Check if the filename matches any in the CSV file
            if filename in filenames:
                # Construct source and destination paths
                src_path = os.path.join(root, filename)
                dest_path = os.path.join(output_folder, filename)
                # Copy the image to the output folder
                shutil.copy(src_path, dest_path)
                print(f"Copied {filename} to {output_folder}")

# Provide the CSV file path, image folder path, and output folder path
csv_file = '/Users/mskamran/Downloads/junk.csv'
image_folder = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/Akshay porichoy All Letters'
output_folder = '/Users/mskamran/Documents/Data Science/final letters process/Akshar Porichoy/Cross Check'

copy_images_matching_csv(csv_file, image_folder, output_folder)
